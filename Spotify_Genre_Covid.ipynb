# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
Top_10s_stream = "file/top_10s.csv"
Top_10s_stream = pd.read_csv(Top_10s_stream, encoding="ISO-8859-1")
Top_10s_stream
# Out:
#      Unnamed: 0                                              title  \
# 0             1                                   Hey, Soul Sister
# 1             2                               Love The Way You Lie
# 2             3                                            TiK ToK
# 3             4                                        Bad Romance
# 4             5                               Just the Way You Are
# ..          ...                                                ...
# 598         599                Find U Again (feat. Camila Cabello)
# 599         600      Cross Me (feat. Chance the Rapper & PnB Rock)
# 600         601  No Brainer (feat. Justin Bieber, Chance the Ra...
# 601         602    Nothing Breaks Like a Heart (feat. Miley Cyrus)
# 602         603                                   Kills You Slowly
#
#                artist        top genre  year  bpm  nrgy  dnce  dB  live  val  \
# 0               Train       neo mellow  2010   97    89    67  -4     8   80
# ...

# %%
Top_10s_stream.rename(columns={"top genre": "genre"}, inplace = True)
Top_10s_stream.genre.unique()
# Out:
# array(['neo mellow', 'detroit hip hop', 'dance pop', 'pop',
#        'canadian pop', 'hip pop', 'barbadian pop', 'atl hip hop',
#        'australian pop', 'indie pop', 'art pop', 'colombian pop',
#        'big room', 'british soul', 'chicago rap', 'acoustic pop',
#        'permanent wave', 'boy band', 'baroque pop', 'celtic rock',
#        'electro', 'complextro', 'canadian hip hop', 'candy pop',
#        'alaska indie', 'folk-pop', 'metropopolis', 'house',
#        'australian hip hop', 'electropop', 'australian dance',
#        'hollywood', 'canadian contemporary r&b',
#        'irish singer-songwriter', 'tropical house', 'belgian edm',
#        'french indie pop', 'hip hop', 'danish pop', 'latin',
#        'canadian latin', 'electronic trap', 'edm', 'electro house',
#        'downtempo', 'brostep', 'contemporary country', 'moroccan pop',
#        'escape room', 'alternative r&b'], dtype=object)

# %%
Top_10s_stream["rank"] = Top_100_stream.reset_index().iloc[:, 0].shift(-1)
Top_10s_stream.at[99, 'rank'] = '100.0'
Top_10s_stream
# Out:
#      Unnamed: 0                                              title  \
# 0             1                                   Hey, Soul Sister
# 1             2                               Love The Way You Lie
# 2             3                                            TiK ToK
# 3             4                                        Bad Romance
# 4             5                               Just the Way You Are
# ..          ...                                                ...
# 598         599                Find U Again (feat. Camila Cabello)
# 599         600      Cross Me (feat. Chance the Rapper & PnB Rock)
# 600         601  No Brainer (feat. Justin Bieber, Chance the Ra...
# 601         602    Nothing Breaks Like a Heart (feat. Miley Cyrus)
# 602         603                                   Kills You Slowly
#
#                artist            genre  year  bpm  nrgy  dnce  dB  live  val  \
# 0               Train       neo mellow  2010   97    89    67  -4     8   80
# ...

# %%
Cleaner_df = Top_10s_stream[["title", "artist", "genre","year", "dnce", "val", "pop"]]
Cleaner_df
# Out:
#                                                  title            artist  \
# 0                                     Hey, Soul Sister             Train
# 1                                 Love The Way You Lie            Eminem
# 2                                              TiK ToK             Kesha
# 3                                          Bad Romance         Lady Gaga
# 4                                 Just the Way You Are        Bruno Mars
# ..                                                 ...               ...
# 598                Find U Again (feat. Camila Cabello)       Mark Ronson
# 599      Cross Me (feat. Chance the Rapper & PnB Rock)        Ed Sheeran
# 600  No Brainer (feat. Justin Bieber, Chance the Ra...         DJ Khaled
# 601    Nothing Breaks Like a Heart (feat. Miley Cyrus)       Mark Ronson
# 602                                   Kills You Slowly  The Chainsmokers
#
#                genre  year  dnce  val  pop
# 0         neo mellow  2010    67   80   83
# ...

# %%
Cleaner_df.rename(columns={"top genre": "genre", "dnce": "danceability", "val": "valence", "pop":"popularity"}, inplace = True)
Cleaner_df.genre.value_counts()
# Out:
# C:\Users\carli\AppData\Local\Temp\ipykernel_40300\3113838690.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Cleaner_df.rename(columns={"top genre": "genre", "dnce": "danceability", "val": "valence", "pop":"popularity"}, inplace = True)
# dance pop                    327
# pop                           60
# canadian pop                  34
# barbadian pop                 15
# boy band                      15
# electropop                    13
# british soul                  11
# big room                      10
# canadian contemporary r&b      9
# neo mellow                     9
# art pop                        8
# complextro                     6
# hip pop                        6
# australian dance               6
# atl hip hop                    5
# australian pop                 5
# ...

# %%
year = Cleaner_df.groupby('year')
year.first()
# Out:
#                          title           artist                      genre  \
# year
# 2010          Hey, Soul Sister            Train                 neo mellow
# 2011          A Thousand Years  Christina Perri                  dance pop
# 2012      Titanium (feat. Sia)     David Guetta                  dance pop
# 2013       Underneath the Tree   Kelly Clarkson                  dance pop
# 2014                 All of Me      John Legend                 neo mellow
# 2015         Thinking out Loud       Ed Sheeran                        pop
# 2016                 The Hills       The Weeknd  canadian contemporary r&b
# 2017              Shape of You       Ed Sheeran                        pop
# 2018  One Kiss (with Dua Lipa)    Calvin Harris                  dance pop
# 2019                  Memories         Maroon 5                        pop
#
#       danceability  valence  popularity
# year
# 2010            67       80          83
# 2011            42       16          81
# ...

# %%
genre_19 = year.get_group(2019)
Genres_19 = genre_19["genre"].value_counts()
Genres_19.plot(kind = 'pie', title="Most Streamed Song Genres of 2019")
plot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_40300\252662702.py in <module>
#       2 Genres_19 = genre_19["genre"].value_counts()
#       3 Genres_19.plot(kind = 'pie', title="Most Streamed Song Genres of 2019")
# ----> 4 plot.show()
#
# NameError: name 'plot' is not defined

# %%
genre_10 = year.get_group(2010)
Genres_10 = genre_10["genre"].value_counts()
Genres_10.plot(kind = 'pie', title="Most Streamed Song Genres of 2010").get_figure()
Genres_10.savefig('plot10.pdf')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_40300\3990217340.py in <module>
#       2 Genres_10 = genre_10["genre"].value_counts()
#       3 Genres_10.plot(kind = 'pie', title="Most Streamed Song Genres of 2010").get_figure()
# ----> 4 Genres_10.savefig('plot10.pdf')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'savefig'

# %%
Top_2020_streamed_path = "file/spotifytop2020.csv"
Top_2020_stream = pd.read_csv(Top_2020_streamed_path, encoding="ISO-8859-1")
Top_2020_stream
# Out:
#     Unnamed: 0           artist  \
# 0            0       The Weeknd
# 1            1      Tones And I
# 2            2      Roddy Ricch
# 3            3        SAINt JHN
# 4            4         Dua Lipa
# 5            5           DaBaby
# 6            6     Harry Styles
# 7            7            Powfu
# 8            8    Trevor Daniel
# 9            9    Lewis Capaldi
# 10          10          KAROL G
# 11          11   Arizona Zervas
# 12          12      Post Malone
# 13          13        Lil Mosey
# 14          14    Justin Bieber
# 15          15            Drake
# 16          16    Lewis Capaldi
# 17          17         Doja Cat
# 18          18         Maroon 5
# 19          19           Future
# 20          20        Jawsh 685
# 21          21     Harry Styles
# 22          22            Topic
# 23          23         24kGoldn
# 24          24    Billie Eilish
# 25          25     Shawn Mendes
# 26          26    Billie Eilish
# 27          27          Cardi B
# ...

# %%
Top_2020_stream.genre.unique()
# Out:
# array(['R&B/Soul', 'Alternative/Indie', 'Hip-Hop/Rap', 'Dance/Electronic',
#        'Nu-disco', 'Pop', 'R&B/Hip-Hop alternative', 'Pop/Soft Rock',
#        'Pop rap', ' Electro-pop', 'Hip-Hop/Trap', 'Dance-pop/Disco',
#        'Disco-pop', 'Dreampop/Hip-Hop/R&B',
#        'Alternative/reggaeton/experimental', 'Chamber pop'], dtype=object)

# %%
Genres = Top_2020_stream["genre"].value_counts()
Genres.plot(kind = 'pie', title="Most Streamed Genres 2020")
plot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_40300\112145586.py in <module>
#       1 Genres = Top_2020_stream["genre"].value_counts()
#       2 Genres.plot(kind = 'pie', title="Most Streamed Genres 2020")
# ----> 3 plot.show()
#
# NameError: name 'plot' is not defined
